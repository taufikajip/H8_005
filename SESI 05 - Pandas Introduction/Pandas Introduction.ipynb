# %% [markdown]
# # Using the Pandas Python Library

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
# Membuat angka dibelakang koma berubah
pd.set_option("display.precision", 2)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# Mencetak baris terakhir
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %%
# Reset option untuk memunculkan jumlah kolom baris
pd.reset_option("display.max.columns")

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...      40.29     NYK    Knicks       68
# 1            0     NYK   Knicks  ...      41.71     TRH   Huskies       66
# 2            0     CHS    Stags  ...      42.01     NYK    Knicks       47
# 3            0     NYK   Knicks  ...      40.69     CHS     Stags       63
# 4            0     DTF  Falcons  ...      38.86     WSC  Capitols       50
#
#   opp_elo_i opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# # Getting to Know Your Data

# %% [markdown]
# ##  Displaying Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ## Showing Basic Statistics

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# df['game_id']
# df[['game_id', 'lg_id']]

df[['game_id', 'lg_id', 'pts']]
# Out:
#              game_id lg_id  pts
# 0       194611010TRH   NBA   66
# 1       194611010TRH   NBA   68
# 2       194611020CHS   NBA   63
# 3       194611020CHS   NBA   47
# 4       194611020DTF   NBA   33
# ...              ...   ...  ...
# 126309  201506110CLE   NBA   82
# 126310  201506140GSW   NBA  104
# 126311  201506140GSW   NBA   91
# 126312  201506170CLE   NBA   97
# 126313  201506170CLE   NBA  105
#
# [126314 rows x 3 columns]

# %%
df['pts'].describe()
# Out:
# count    126314.00
# mean        102.73
# std          14.81
# min           0.00
# 25%          93.00
# 50%         103.00
# 75%         112.00
# max         186.00
# Name: pts, dtype: float64

# %%
df[['pts', 'elo_i']].describe()
# Out:
#              pts      elo_i
# count  126314.00  126314.00
# mean      102.73    1495.24
# std        14.81     112.14
# min         0.00    1091.64
# 25%        93.00    1417.24
# 50%       103.00    1500.95
# 75%       112.00    1576.06
# max       186.00    1853.10

# %%
df.describe(include=object)
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     196911050ATL     NBA  4/16/2014     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                A           W  at New York NY
# freq           63138       63157             440

# %% [raw]
# top untuk object = yang sering muncul

# %%
df.describe(include=[object,int])
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     196911050ATL     NBA  4/16/2014     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                A           W  at New York NY
# freq           63138       63157             440

# %% [markdown]
# ## Exploring Your Dataset

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# PIT      60
# INJ      60
# DTF      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
fran_lakers = df['fran_id'] == 'Lakers'
df[fran_lakers]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %% [raw]
# Dapat dilihat tim bernama "Lakers" memainkan 6024 pertandingan, tetapi hanya 5078 yang dimainkan Los Angeles Lakers. Maka kita cari tahu total pertandingan tim "Lakers" lainnya, yakni MNL.

# %%
# (Cara 1) Melihat tim franchise "Lakers" lainnya
df[fran_lakers]['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
# (Cara 2) Melihat tim franchise "Lakers" lainnya
df.loc[df["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %% [raw]
# Memang, Minneapolis Lakers ("MNL") memainkan 946 pertandingan. Kita cari tahu kapan mereka memainkan game-game itu

# %%
# Cara 1
df.loc[df["team_id"] == "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
# Cara 2
mnl_team = df['team_id'] == 'MNL'
df[mnl_team]['date_game'].min()
# Out:
# '1/1/1949'

# %%
# Cara 1
df.loc[df["team_id"] == "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
# Cara 2
mnl_team = df['team_id'] == 'MNL'
df[mnl_team]['date_game'].max()
# Out:
# '4/9/1959'

# %% [raw]
# Menggabungkan 2 rentang tanggal menjadi satu

# %%
# Cara 1
df.loc[df["team_id"] == "MNL", "date_game"].agg(("min","max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
# Cara 2
df[mnl_team]['date_game'].agg(['min','max'])
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %% [raw]
# Misal mencari poin minimum dan maksimum dari tim MNL

# %%
df[mnl_team]['pts'].agg(['min','max'])
# Out:
# min     18
# max    139
# Name: pts, dtype: int64

# %%
fran_nuggets = df['fran_id'] == 'Nuggets'
df[fran_nuggets]['team_id']
df[fran_nuggets]['team_id'].value_counts()
# Out:
# DEN    3312
# DNR     614
# DNA     194
# Name: team_id, dtype: int64

# %% [raw]
# Mencari tahu berapa banyak poin yang dicetak Boston Celtics "BOS" selama semua pertandingan.

# %%
# Cara 1
df.loc[df["team_id"] == "BOS", "pts"].sum()
# Out:
# 626484

# %%
# Cara 2
bos_team = df['team_id'] == 'BOS'
df[bos_team]['pts'].sum()
# Out:
# 626484

# %% [markdown]
# # Getting to Know Pandas' Data Structure

# %% [markdown]
# ## Understanding Series Objects

# %% [raw]
# Membuat objek series baru

# %%
revenues = pd.Series([5555,7000,1980])
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %% [raw]
# Objek Series mempunyai dua komponen:
# 1. A sequence of values
# 2. A sequence of identifiers, which is the index

# %% [raw]
# Values yang 5555 dst ; index yang 0,1,2

# %% [raw]
# revenues.values mengembalikan nilai dalam series, sedangkan revenues.index mengembalikan indeks posisi

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [raw]
# Series jg dapat memiliki jenis indeks yang berubah-ubah. Kita dapat menganggap indeks eksplisit ini sebagai label utk baris tertentu.

# %%
# Initiating/creating Series with explicit index #1
city_revenues = pd.Series(
    [4200,8000,6500],
    index=["Amsterdam","Toronto","Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %% [raw]
# Indeksnya diwakili oleh string

# %%
# Positional Index
city_revenues[0]
# Out:
# 4200

# %%
# Label Index
city_revenues['Amsterdam']
# Out:
# 4200

# %%
city_revenues.keys
# Out:
# <bound method Series.keys of Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64>

# %% [raw]
# # Cara membuat series dengan indeks label dari dictionary Python (City Employee)

# %%
city_employee_count = pd.Series({"Amsterdam":5, "Tokyo":8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %% [raw]
# Dictionary keys menjadi INDEKS, dan nilai dictionary adalah nilai SERIES
#
# Sama seperti dictionaries, Series juga mendukung .keys() dan keyword in

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %% [raw]
# Kita dapat menggunakan metode ini utk menjawab pertanyaan tentang kumpulan data kita dengan cepat

# %% [markdown]
# ##  Understanding DataFrame Objects

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
"NaN --> np.nan"
# Out:
# 'NaN --> np.nan'

# %% [raw]
# Pandas mengganti nilai employee_count yang hilang untuk TORONTO dengan NaN

# %% [raw]
# Indeks DataFrame baru adalah gabungan dari dua indeks Series:

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %% [raw]
# Sama seperti Series, DataFrame juga menyimpan nilai dalam array NumPy

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %% [raw]
# Dapat merujuk ke 2 dimensi DataFrame sebagai axes

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0] #rows
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1] #columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %% [raw]
# Axis bertanda 0 = indeks baris
# Axis bertanda 1 = indeks kolom

# %% [raw]
# DataFrame jg merupakan struktur data seperti Dictionary, sehingga jg mendukung .keys() dan keyword in. Namun utk DataFrame, hal ini tidak terkait dengan indeks, tetapi dengan kolom:

# %%
city_data.keys() # Akan memunculkan indeks kolom
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
"revenue" in city_data
# Out:
# True

# %% [raw]
# Kita akan mencoba mengimplementasikan dengan kumpulan data NBA yang lebih besar. Apakah dataset tsb berisi kolom yang disebut "points" atau "pts"?

# %% [markdown]
# Karena kita tidak menentukan kolom indeks saat membaca file tsb, pandas telah menerapkan RangeIndex ke DataFrame:

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %% [raw]
# df, seperti semua objek Dataframe, memiliki dua axes

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %% [raw]
# Kita dapat memeriksa keberadaan kolom dengan .keys()

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# ##  Accessing Series Elements

# %% [raw]
# # Using the Indexing Operator
#
# Series memiliki dua indeks:
# 1. A positional or implicit index = RangeIndex
# 2. A label or explicit index = contain any hashable objects

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %% [raw]
# Kita dengan mudah dapat mengakses nilai dlm Series dengan indeks Label dan Posisi.

# %%
# Indeks Label
city_revenues["Toronto"]
# Out:
# 8000

# %%
# Indeks Posisi
city_revenues[1]
# Out:
# 8000

# %% [raw]
# Dapat juga untuk indeks dan slicing negatif

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %% [raw]
# # Using .loc dan .iloc

# %%
# Menggunakan indeks manual

colors = pd.Series(
    ["red","purple","blue","green","yellow"],
    index=[1,2,3,5,8]
)

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %% [raw]
# .loc untuk label index
# .iloc untuk positional index

# %%
colors.loc[1]  # .loc Menerapkan indeks manual yang ada (Memanggil explicit index)
# Out:
# 'red'

# %%
colors.loc[5] # .loc Menerapkan indeks manual yang ada (Memanggil explicit index)
# Out:
# 'green'

# %%
colors.iloc[0] # .iloc Menerapkan indeks otomatis 0,1,2,dst (Memanggil implicit index)
# Out:
# 'red'

# %%
colors.iloc[1]  # .iloc Menerapkan indeks otomatis 0,1,2,dst (Memanggil implicit index)
# Out:
# 'purple'

# %%
# Mengembalikan elemen dengan implicit index: 1,2

colors.iloc[1:3]

# .iloc mengecualikan indeks posisi 3 (elemen penutup)
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
# Mengembalikan elemen dengan explicit index diantara 3 dan 8

colors.loc[3:8]

# Di sisi lain, .loc menyertakan elemen penutup
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
# Dapat menyertakan indeks posisi negatif ke .iloc

colors.iloc[-2]
# Out:
# 'green'

# %% [raw]
# - .iloc digunakan untuk Series yang mirip dengan [] pada list
# - .loc digunakan untuk Series yang mirip dengan [] pada dictionary

# %% [raw]
# - Slicing list python : start inclusive, stopnya exclusive
# - Slicing loc : start inclusive, stopnya inclusive
# - Slicing iloc: start inclusive, stopnya exclusive

# %% [markdown]
# ##  Accessing Series Elements

# %%
# Using the Indexing Operator
city_data["revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %% [markdown]
# kedua sintaks tersebut mengembalikan output yang sama

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape":"sphere"},
    {"name": "Rubik's cube", "shape":"cube"}
])

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
# Using .loc dan .iloc

city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.loc["Tokyo":"Toronto"]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1700.74
# elo_n                 1692.09
# win_equiv               59.29
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1813.63
# opp_elo_n             1822.29
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %%
df.iloc[-2010]
# Out:
# gameorder               62153
# game_id          201412080WAS
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           12/8/2014
# seasongame                 20
# is_playoffs                 0
# team_id                   WAS
# fran_id               Wizards
# pts                       133
# elo_i                 1560.87
# elo_n                  1562.1
# win_equiv               46.99
# opp_id                    BOS
# opp_fran              Celtics
# opp_pts                   132
# opp_elo_i             1401.85
# opp_elo_n             1400.62
# game_location               H
# game_result                 W
# forecast                 0.82
# notes                     NaN
# Name: 124304, dtype: object

# %%
df.loc[124304]
# Out:
# gameorder               62153
# game_id          201412080WAS
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           12/8/2014
# seasongame                 20
# is_playoffs                 0
# team_id                   WAS
# fran_id               Wizards
# pts                       133
# elo_i                 1560.87
# elo_n                  1562.1
# win_equiv               46.99
# opp_id                    BOS
# opp_fran              Celtics
# opp_pts                   132
# opp_elo_i             1401.85
# opp_elo_n             1400.62
# game_location               H
# game_result                 W
# forecast                 0.82
# notes                     NaN
# Name: 124304, dtype: object

# %%
# masih using indexing
fran_nuggets = df['fran_id'] == 'Nuggets'
df[fran_nuggets]['team_id']

# %%
city_data.loc["Amsterdam": "Tokyo", "revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: revenue, dtype: int64

# %%
city_data.loc["Amsterdam": "Tokyo", ["revenue", "employee_count"]]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
df.loc[5555:5559, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %%
df.loc[:5, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#     fran_id  opp_fran  pts  opp_pts
# 0   Huskies    Knicks   66       68
# 1    Knicks   Huskies   68       66
# 2     Stags    Knicks   63       47
# 3    Knicks     Stags   47       63
# 4   Falcons  Capitols   33       50
# 5  Capitols   Falcons   50       33

# %% [markdown]
# # Querying Your Dataset

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
current_decade = df[df["year_id"]>2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
# current_decade = df[df["year_id"]>2010] , di break down
games_after_2010 = df["year_id"] > 2010
current_decade = df[games_after_2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
games_by_year = df["year_id"] > 2004
current_decade = df[games_by_year]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 97886       48944  200411020DAL   NBA        1     2005  11/2/2004
# 97887       48944  200411020DAL   NBA        0     2005  11/2/2004
# 97888       48945  200411020DET   NBA        1     2005  11/2/2004
# 97889       48945  200411020DET   NBA        0     2005  11/2/2004
# 97890       48946  200411020LAL   NBA        0     2005  11/2/2004
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 97886            1            0     SAC      Kings   98  1598.17  1591.60
# ...

# %%
current_decade.shape
# Out:
# (28428, 23)

# %%
games_with_notes = df[df["notes"].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
games_with_notes.shape
# Out:
# (5424, 23)

# %%
ers = df[df["fran_id"].str.endswith("ers")]
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
ers.shape
# Out:
# (27797, 23)

# %%
filt = (
	(df["_iscopy"] == 0) &
	(df["pts"] > 100) &
	(df["opp_pts"] > 100) &
	(df["team_id"] == "BLB")
)
df[filt]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
df[
    (df["_iscopy"]==0) &
    (df["pts"]>100) &
    (df["opp_pts"]>100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
df[
    (df["_iscopy"]==0) &
    (df["team_id"].str.startswith("LA"))&
    (df["year_id"] -- 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9770        4886  196011020LAL   NBA        0     1961   11/2/1960
# 9782        4892  196011060LAL   NBA        0     1961   11/6/1960
# 9786        4894  196011090LAL   NBA        0     1961   11/9/1960
# 9877        4939  196011290LAL   NBA        0     1961  11/29/1960
# 10002       5002  196012290LAL   NBA        0     1961  12/29/1960
# 10117       5059  196101220LAL   NBA        0     1961   1/22/1961
# 10166       5084  196102020LAL   NBA        0     1961    2/2/1961
# 10260       5131  196102200LAL   NBA        0     1961   2/20/1961
# 10307       5154  196103010LAL   NBA        0     1961    3/1/1961
# 10311       5156  196103020LAL   NBA        0     1961    3/2/1961
# 11302       5652  196211150LAL   NBA        0     1963  11/15/1962
# 11424       5713  196212090LAL   NBA        0     1963   12/9/1962
# 11639       5820  196301250LAL   NBA        0     1963   1/25/1963
# ...

# %% [markdown]
# # Grouping and Aggregating Your Data

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
city_revenues.min()
# Out:
# 4200

# %%
city_revenues.mean()
# Out:
# 6233.333333333333

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
points = df["pts"]
points
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %%
points.sum()
# Out:
# 12976235

# %%
df['pts'].sum()
# Out:
# 12976235

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.0  1309.65      42.01    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# 1  Huskies       66    1300.00    1293.28             A           W      0.36
# 2   Knicks       47    1306.72    1297.07             H           W      0.63
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df.groupby("fran_id", sort=False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df.groupby("fran_id", sort=False)["pts"].sum().sort_values()
# Out:
# fran_id
# Ironmen           3674
# Falcons           3797
# Huskies           3995
# Rebels            4474
# Jets              4482
# Denver            4818
# Waterloo          4921
# Redskins          5372
# Packers           6193
# Steamrollers     12372
# Bombers          17793
# Stags            20398
# Capitols         22387
# Olympians        22864
# Sails            30080
# Baltimore        37219
# Floridians       49568
# Condors          49642
# Sounds           75582
# Hornets          84489
# Stars            84940
# Spirits          85874
# Squires          91127
# Colonels         94435
# Grizzlies       157683
# Raptors         158370
# Timberwolves    207693
# Magic           219436
# Pelicans        220794
# Heat            229103
# Mavericks       309239
# Jazz            363155
# Cavaliers       380416
# Clippers        380523
# Trailblazers    402695
# Nets            417809
# Bucks           418326
# Rockets         432504
# Bulls           437269
# ...

# %%
df.groupby("team_id", sort=False)["pts"]

# %%
df.groupby("team_id", sort=False)["pts"].sum().sort_values()
# Out:
# team_id
# SDS      1087
# PIT      3674
# DTF      3797
# TRH      3995
# CLR      4474
#         ...
# PHI    472991
# DET    516438
# LAL    549215
# NYK    582497
# BOS    626484
# Name: pts, Length: 104, dtype: int64

# %%
type(city_revenues)
# Out:
# pandas.core.series.Series

# %%
df[
    (df["fran_id"] == "Spurs") & 
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
	(df["fran_id"] == "Spurs") &
	(df["year_id"] > 2010)
].groupby(["game_result"])["game_id"].count()
# Out:
# game_result
# L    133
# W    332
# Name: game_id, dtype: int64

# %%
df[
	(df["fran_id"] == "Warriors") &
	(df["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
df[
	(df["fran_id"] == "Warriors") &
	(df["year_id"] == 2015)
].groupby(["game_result", "is_playoffs"])["game_id"].count()
# Out:
# game_result  is_playoffs
# L            0              15
#              1               5
# W            0              67
#              1              16
# Name: game_id, dtype: int64

# %% [markdown]
# # Manipulating Columns

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
nba = df.copy()

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba["difference"]  = df.pts - df.opp_pts

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba[['pts', 'opp_pts', 'difference']]
# Out:
#         pts  opp_pts  difference
# 0        66       68          -2
# 1        68       66           2
# 2        63       47          16
# 3        47       63         -16
# 4        33       50         -17
# ...     ...      ...         ...
# 126309   82      103         -21
# 126310  104       91          13
# 126311   91      104         -13
# 126312   97      105          -8
# 126313  105       97           8
#
# [126314 rows x 3 columns]

# %%
nba["difference"].max()
# Out:
# 68

# %%
nba["difference"].value_counts()
# Out:
#  2     4115
# -2     4115
#  5     4001
# -5     4001
# -7     3912
#        ...
#  68       1
# -63       1
#  65       1
#  63       1
# -65       1
# Name: difference, Length: 126, dtype: int64

# %%
renamed_nba = nba.rename(
    columns={"game_result": "result", "game_location":"location"}
)
renamed_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n location result  forecast notes  \
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba.drop(elo_columns, inplace=True, axis=1)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.shape
# Out:
# (126314, 20)

# %% [markdown]
# # Specifying Data Types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
# ...

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])

# %%
nba["date_game"].nunique()
# Out:
# 12426

# %%
nba["game_location"].nunique()
# Out:
# 3

# %%
nba["game_location"].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])

# %%
nba["game_location"].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# # Missing Values

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %%
rows_without_missing_data = nba.dropna() #Axis = 0 -- baris

# %%
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_without_missing_columns = nba.dropna(axis=1) # Axis = 1 -- Kolom 
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = df.copy()
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)

# %%
data_with_default_notes['notes']
# Out:
# 0         no notes at all
# 1         no notes at all
# 2         no notes at all
# 3         no notes at all
# 4         no notes at all
#                ...
# 126309    no notes at all
# 126310    no notes at all
# 126311    no notes at all
# 126312    no notes at all
# 126313    no notes at all
# Name: notes, Length: 126314, dtype: object

# %%
data_with_default_notes['notes'].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# # Invalid Values

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast  difference
# count  126314.00  126314.00  126314.00   126314.00
# mean       41.71     102.73       0.50        0.00
# std        10.63      14.81       0.22       13.37
# min        10.15       0.00       0.02      -68.00
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L      0.33  at Richmond VA; forfeit to VIR
#
#        difference
# 26684          -2

# %%
# Inconsistent Values

nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["game_result"] != 'L')].empty
# Out:
# True

# %% [markdown]
# # Combining Multiple Datasets

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000,3400], "employee_count": [2,2]},
    index=['New York', 'Barcelona']
)

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1,1,0,0,0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join='inner')
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population_millions": [17,127,37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland", "Japan", "Canada"])

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# # Visualizing Your Pandas DataFrame

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba["fran_id"].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64

# %% [markdown]
# # TipSy

# %% [raw]
# 'line' : line plot (default)
# 'bar' : vertical bar plot
# 'barh' : horizontal bar plot
# 'hist' : histogram
# 'box' : boxplot
# 'kde' : Kernel Density Estimation plot
# 'density' : same as 'kde'
# 'area' : area plot
# 'pie' : pie plot
# 'scatter' : scatter plot
# 'hexbin' : hexbin plot
